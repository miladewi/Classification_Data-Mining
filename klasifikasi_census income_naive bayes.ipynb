# %% [markdown]
# ## Import Library

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, OrdinalEncoder
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import KBinsDiscretizer

# %% [markdown]
# ## Load Data

# %%
data = r'census_income_fix.csv'
data = pd.read_csv(data)
data.head()
# Out:
#    Age         Workclass  Fnlwgt  Education  Education-Num  \
# 0   38           Private  215646    HS-grad              9
# 1   53           Private  234721       11th              7
# 2   28           Private  338409  Bachelors             13
# 3   37           Private  284582    Masters             14
# 4   52  Self-emp-not-inc  209642    HS-grad              9
#
#         MatrialStatus         Occupation   Relationship   Race     Sex  \
# 0            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 3  Married-civ-spouse    Exec-managerial           Wife  White  Female
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    CapitalGain  CapitalLoss  Hoursperweek        Country Target Outlier  \
# 0            0            0            40  United-States  <=50K      no
# 1            0            0            40  United-States  <=50K      no
# 2            0            0            40           Cuba  <=50K      no
# 3            0            0            40  United-States  <=50K      no
# 4            0            0            45  United-States   >50K      no
#
#   ExtremeValue
# 0           no
# 1           no
# 2           no
# 3           no
# 4           no

# %% [markdown]
# ## Cek Missing Value

# %%
data.isna().sum()
# Out:
# Age              0
# Workclass        0
# Fnlwgt           0
# Education        0
# Education-Num    0
# MatrialStatus    0
# Occupation       0
# Relationship     0
# Race             0
# Sex              0
# CapitalGain      0
# CapitalLoss      0
# Hoursperweek     0
# Country          0
# Target           0
# Outlier          0
# ExtremeValue     0
# dtype: int64

# %% [markdown]
# ## Cek Duplicate

# %%
duplicate = data[data.duplicated()]
duplicate.shape
# Out:
# (20, 17)

# %%
data = data.drop_duplicates(keep='first')
data.shape
# Out:
# (24281, 17)

# %% [markdown]
# ## Analisis Data

# %%
#analisis data pada kolom target
data['Target'].describe()
# Out:
# count     24281
# unique        2
# top       <=50K
# freq      19338
# Name: Target, dtype: object

# %%
#merubah nilai pada kolom target dengan satuan integer
def string_int(x):
    if x == '<=50K':
        return 1
    if x == '>50K':
        return 2
data['Trans_Target'] = data['Target'].apply(string_int)

# %% [markdown]
# ## Pemilihan Variabel (kolom)

# %%
data.drop(['Outlier','ExtremeValue'], axis =1 , inplace=True)

# %% [markdown]
# ## Label Encoder

# %%
labelencoder = LabelEncoder()
#data['Age_trans'] = labelencoder.fit_transform(data['Age'])
data['Workclass_trans'] = labelencoder.fit_transform(data['Workclass'])
data['Education_trans'] = labelencoder.fit_transform(data['Education'])
data['MatrialStatus_trans'] = labelencoder.fit_transform(data['MatrialStatus'])
data['Occupation_trans'] = labelencoder.fit_transform(data['Occupation'])
data['Relationship_trans'] = labelencoder.fit_transform(data['Relationship'])
data['Race_trans'] = labelencoder.fit_transform(data['Race'])
data['Sex_trans'] = labelencoder.fit_transform(data['Sex'])
data['Country_trans'] = labelencoder.fit_transform(data['Country'])
data.head()
# Out:
#    Age         Workclass  Fnlwgt  Education  Education-Num  \
# 0   38           Private  215646    HS-grad              9
# 1   53           Private  234721       11th              7
# 2   28           Private  338409  Bachelors             13
# 3   37           Private  284582    Masters             14
# 4   52  Self-emp-not-inc  209642    HS-grad              9
#
#         MatrialStatus         Occupation   Relationship   Race     Sex  ...  \
# 0            Divorced  Handlers-cleaners  Not-in-family  White    Male  ...
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male  ...
# 2  Married-civ-spouse     Prof-specialty           Wife  Black  Female  ...
# 3  Married-civ-spouse    Exec-managerial           Wife  White  Female  ...
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male  ...
#
#    Target  Trans_Target  Workclass_trans Education_trans MatrialStatus_trans  \
# 0   <=50K             1                3              11                   0
# 1   <=50K             1                3               1                   2
# 2   <=50K             1                3               9                   2
# 3   <=50K             1                3              12                   2
# 4    >50K             2                5              11                   2
#
#    Occupation_trans  Relationship_trans  Race_trans  Sex_trans  Country_trans
# 0                 5                   1           4          1             37
# 1                 5                   0           2          1             37
# 2                 9                   5           2          0              4
# 3                 3                   5           4          0             37
# 4                 3                   0           4          1             37
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Discretization

# %%
enc = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
X_binned = enc.fit_transform(data[['Age']])
data['trans_age'] = X_binned
data.head()
# Out:
#    Age         Workclass  Fnlwgt  Education  Education-Num  \
# 0   38           Private  215646    HS-grad              9
# 1   53           Private  234721       11th              7
# 2   28           Private  338409  Bachelors             13
# 3   37           Private  284582    Masters             14
# 4   52  Self-emp-not-inc  209642    HS-grad              9
#
#         MatrialStatus         Occupation   Relationship   Race     Sex  ...  \
# 0            Divorced  Handlers-cleaners  Not-in-family  White    Male  ...
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male  ...
# 2  Married-civ-spouse     Prof-specialty           Wife  Black  Female  ...
# 3  Married-civ-spouse    Exec-managerial           Wife  White  Female  ...
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male  ...
#
#    Trans_Target  Workclass_trans  Education_trans MatrialStatus_trans  \
# 0             1                3               11                   0
# 1             1                3                1                   2
# 2             1                3                9                   2
# 3             1                3               12                   2
# 4             2                5               11                   2
#
#   Occupation_trans  Relationship_trans  Race_trans  Sex_trans  Country_trans  \
# 0                5                   1           4          1             37
# 1                5                   0           2          1             37
# 2                9                   5           2          0              4
# 3                3                   5           4          0             37
# 4                3                   0           4          1             37
#
#    trans_age
# 0        1.0
# 1        2.0
# 2        0.0
# 3        1.0
# 4        2.0
#
# [5 rows x 25 columns]

# %%
enc = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
X_binned = enc.fit_transform(data[['Fnlwgt']])
data['trans_Fnlwgt'] = X_binned
data.head()
# Out:
#    Age         Workclass  Fnlwgt  Education  Education-Num  \
# 0   38           Private  215646    HS-grad              9
# 1   53           Private  234721       11th              7
# 2   28           Private  338409  Bachelors             13
# 3   37           Private  284582    Masters             14
# 4   52  Self-emp-not-inc  209642    HS-grad              9
#
#         MatrialStatus         Occupation   Relationship   Race     Sex  ...  \
# 0            Divorced  Handlers-cleaners  Not-in-family  White    Male  ...
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male  ...
# 2  Married-civ-spouse     Prof-specialty           Wife  Black  Female  ...
# 3  Married-civ-spouse    Exec-managerial           Wife  White  Female  ...
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male  ...
#
#    Workclass_trans  Education_trans  MatrialStatus_trans Occupation_trans  \
# 0                3               11                    0                5
# 1                3                1                    2                5
# 2                3                9                    2                9
# 3                3               12                    2                3
# 4                5               11                    2                3
#
#   Relationship_trans  Race_trans  Sex_trans  Country_trans  trans_age  \
# 0                  1           4          1             37        1.0
# 1                  0           2          1             37        2.0
# 2                  5           2          0              4        0.0
# 3                  5           4          0             37        1.0
# 4                  0           4          1             37        2.0
#
#    trans_Fnlwgt
# 0           3.0
# 1           3.0
# 2           5.0
# 3           4.0
# 4           3.0
#
# [5 rows x 26 columns]

# %%
enc = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
X_binned = enc.fit_transform(data[['Hoursperweek']])
data['trans_Hoursperweek'] = X_binned
data.head()
# Out:
#    Age         Workclass  Fnlwgt  Education  Education-Num  \
# 0   38           Private  215646    HS-grad              9
# 1   53           Private  234721       11th              7
# 2   28           Private  338409  Bachelors             13
# 3   37           Private  284582    Masters             14
# 4   52  Self-emp-not-inc  209642    HS-grad              9
#
#         MatrialStatus         Occupation   Relationship   Race     Sex  ...  \
# 0            Divorced  Handlers-cleaners  Not-in-family  White    Male  ...
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male  ...
# 2  Married-civ-spouse     Prof-specialty           Wife  Black  Female  ...
# 3  Married-civ-spouse    Exec-managerial           Wife  White  Female  ...
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male  ...
#
#    Education_trans  MatrialStatus_trans  Occupation_trans Relationship_trans  \
# 0               11                    0                 5                  1
# 1                1                    2                 5                  0
# 2                9                    2                 9                  5
# 3               12                    2                 3                  5
# 4               11                    2                 3                  0
#
#   Race_trans  Sex_trans  Country_trans  trans_age  trans_Fnlwgt  \
# 0          4          1             37        1.0           3.0
# 1          2          1             37        2.0           3.0
# 2          2          0              4        0.0           5.0
# 3          4          0             37        1.0           4.0
# 4          4          1             37        2.0           3.0
#
#    trans_Hoursperweek
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 5.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Pembagian Data

# %%
X = data[['trans_age','Workclass_trans','trans_Fnlwgt','Education_trans','Education-Num','MatrialStatus_trans','Occupation_trans','Relationship_trans','Race_trans','Sex_trans','trans_Hoursperweek','Country_trans']]
y = data[['Target']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (19440, 12)
# (19440, 1)
# (4861, 12)
# (4861, 1)

# %% [markdown]
# ## Klasifikasi

# %%
NaiveBayes = MultinomialNB().fit(X_train,np.ravel(y_train,order='c'))
print(NaiveBayes)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prediction = NaiveBayes.predict(X_test)
print(prediction)

from sklearn.metrics import classification_report
print(classification_report(y_test, prediction))
# Out:
# ['<=50K' '<=50K' '<=50K' ... '>50K' '<=50K' '<=50K']
#               precision    recall  f1-score   support
#
#        <=50K       0.87      0.90      0.88     15449
#         >50K       0.54      0.48      0.51      3991
#
#     accuracy                           0.81     19440
#    macro avg       0.71      0.69      0.70     19440
# weighted avg       0.80      0.81      0.81     19440
